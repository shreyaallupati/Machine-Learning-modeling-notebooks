# %% [markdown]
# ## MATPLOTLIB

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot();

# %%
plt.plot([1,2,3,4])

# %%
x=[1,2,3,4]
y=[11,22,33,44]
plt.plot(x,y);

# %%
#method1
fig = plt.figure()
ax= fig.add_subplot()
plt.show()

# %%
#method2
fig = plt.figure()
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y)
plt.show()

# %%
#method3
fig, ax = plt.subplots()
ax.plot(x,y)
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._axes.Axes)

# %% [markdown]
# # matplotlib ex workflow

# %%
import matplotlib.pyplot as plt

#1. prepare data
x=[1,2,3,4]
y=[11,22,33,44]

#2. setup plot
fig, ax = plt.subplots()

#3. plot data
ax.plot(x,y)

#4. customize plot
ax.set(title="simple plot",
       xlabel="x-axis",
       ylabel="y-axis")

#5. save n show
fig.savefig("sample-plot.png")

# %% [markdown]
# ## making figures with numpy arrays
#
# we want:
# *line plot
# *scatter plot
# *bar plot
# *histogram
# *subplots

# %%
import numpy as np

# %%
# create some data
x = np.linspace(0,1,100)
x[:10]
# Out:
# array([0.        , 0.01010101, 0.02020202, 0.03030303, 0.04040404,
#        0.05050505, 0.06060606, 0.07070707, 0.08080808, 0.09090909])

# %%
# plot the data
fig, ax = plt.subplots()
ax.plot(x,x**2);

# %%
fig , ax = plt.subplots()
ax.scatter(x, np.exp(x));

# %%
fig, ax = plt.subplots()
ax.scatter(x,np.sin(x));

# %%
#make a plot from dictionary
nut_butter_prices ={"almond":10, "peanut":8, "cashew":12}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax.set(title="nut butter prices",ylabel="price");

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()),list(nut_butter_prices.values()));

# %%
x = np.random.randn(1000)
fig, ax=plt.subplots()
ax.hist(x);

# %%
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,figsize=(10,5))
ax1.plot(x,x/2)
ax2.scatter(x,x)
ax3.bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax4.hist(x=np.random.randn(1000));

# %%
fig, ax = plt.subplots(nrows=2,ncols=2,figsize=(10,5))
ax[0,0].plot(x,x/2)
ax[0,1].scatter(x,x)
ax[1,0].bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax[1,1].hist(x=np.random.randn(1000));

# %% [markdown]
# ## plotting from pandas dataframes

# %%
car_sales=pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts=pd.Series(np.random.randn(1000),index=pd.date_range("1/1/2020",periods=1000))
ts= ts.cumsum()
ts.plot()
# Out:
# <Axes: >

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '', regex=True).astype(int)
car_sales
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_27696\2720696972.py:1: SyntaxWarning: invalid escape sequence '\$'
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '', regex=True).astype(int)
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Price"] = car_sales["Price"].astype(str)

# %%
car_sales["Price"] = car_sales["Price"].str[:-2]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sale Date"]=pd.date_range("1/1/2020",periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
car_sales["total sales"]=car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  total sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
car_sales.plot(x="Sale Date", y="total sales");

# %%
car_sales["Price"]=car_sales["Price"].astype(int)
car_sales.plot(x="Odometer (KM)", y="Price",kind="scatter");

# %%
x = np.random.randn(10,4)

df= pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0 -1.754890  1.565534  0.017168  1.437158
# 1  1.463763 -0.039580  0.441150 -0.934244
# 2  0.097648  1.491058 -1.163334 -0.545831
# 3 -0.099079  0.584955  0.146592  0.629685
# 4  0.228456 -0.308937 -0.275390  2.365213
# 5 -1.746746  0.268097  0.725909  0.677359
# 6  0.318800 -0.253075 -1.678562  1.079264
# 7  1.675895 -0.128366 -0.651011  0.891495
# 8 -1.643954  1.614282 -0.018431  0.416288
# 9 -0.319254  2.535128  0.824877  1.253950

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
df.plot(kind="bar")
# Out:
# <Axes: >

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  total sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
car_sales.plot("Make","Odometer (KM)",kind="bar")
# Out:
# <Axes: xlabel='Make'>

# %%
car_sales["Odometer (KM)"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease["age"].plot.hist(bins=10);

# %%
heart_disease.plot.hist(figsize=(10,30),subplots=True);

# %% [markdown]
# ## which one should you choose? pyplot vs matplotlib OO method?
# #=>when plotting something quickly, its ok to use pyplot
# #=> when plotting somethiing more advanced, use the OO method

# %%
over_50 = heart_disease[heart_disease["age"] > 50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
#pyplot method
over_50.plot(kind="scatter",x="age",y="chol",c="target");

# %%
#oo method
fix, ax= plt.subplots(figsize=(10,6))
over_50.plot(kind="scatter",x="age",y="chol",c="target",ax=ax);
#ax.set_xlim([45,100])

# %%
#oo method from scratch
fig, ax= plt.subplots(figsize=(10,6))

scatter= ax.scatter(x=over_50["age"],
                    y=over_50["chol"],
                    c=over_50["target"])

#customize
ax.set(title="heart diease n chol levels",
       xlabel="age",
       ylabel="chol")

#add a legend
ax.legend(*scatter.legend_elements(),title="target");

#add a horizontal line
ax.axhline(over_50["chol"].mean(),
           linestyle="--");

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
#subpllot of chol,age, thalach
fig, (ax0,ax1) = plt.subplots(nrows=2,
                              ncols=1,
                              figsize=(10,10),
                             sharex=True)
scatter= ax0.scatter(x=over_50["age"],
                     y=over_50["chol"],
                     c=over_50["target"])

#customize ax0
ax0.set(title="heart disease and chol levels",
        ylabel="chol")
ax0.legend(*scatter.legend_elements(),title="target")
ax0.axhline(y=over_50["chol"].mean(),
            linestyle="--")

scatter= ax1.scatter(x=over_50["age"],
                     y=over_50["thalach"],
                     c=over_50["target"])

#customize ax1
ax1.set(title="heart disease and chol levels",
        xlabel="age",
        ylabel="thalach")
ax1.legend(*scatter.legend_elements(),title="target")
ax1.axhline(y=over_50["thalach"].mean(),
            linestyle="--")


#add title to fig
fig.suptitle("heart disease analysis",fontsize=16,fontweight="bold");

# %% [markdown]
# ## customzing plots and make em stylish

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales["Price"].plot();

# %%
plt.style.use('seaborn-v0_8-whitegrid')

# %%
car_sales["Price"].plot();

# %%
plt.style.use('ggplot')

# %%
car_sales["Price"].plot();

# %%
x = np.random.randn(10,4)
x
# Out:
# array([[ 0.26011434, -0.76879226,  0.06584996, -1.91370038],
#        [ 0.11474587, -0.19790756, -0.41843716, -1.04629564],
#        [ 1.31484709,  0.65876808, -0.87811244,  0.64922848],
#        [ 0.26562138,  1.08225817, -0.47389506, -0.78165099],
#        [-1.17699767,  0.69324805,  1.06127427, -1.2791301 ],
#        [ 1.18340615, -1.25747681,  1.4491941 , -0.25809009],
#        [-0.19700171, -0.62258284,  0.0176837 ,  0.37882267],
#        [ 0.13291379, -1.34850813, -0.57747153, -0.09779861],
#        [-0.0209873 , -1.74180889,  0.46457368, -1.61067371],
#        [ 1.06464384, -1.31016369,  0.94001491, -0.16354282]])

# %%
df= pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.260114 -0.768792  0.065850 -1.913700
# 1  0.114746 -0.197908 -0.418437 -1.046296
# 2  1.314847  0.658768 -0.878112  0.649228
# 3  0.265621  1.082258 -0.473895 -0.781651
# 4 -1.176998  0.693248  1.061274 -1.279130
# 5  1.183406 -1.257477  1.449194 -0.258090
# 6 -0.197002 -0.622583  0.017684  0.378823
# 7  0.132914 -1.348508 -0.577472 -0.097799
# 8 -0.020987 -1.741809  0.464574 -1.610674
# 9  1.064644 -1.310164  0.940015 -0.163543

# %%
ax=df.plot(kind="bar")
type(ax)
# Out:
# matplotlib.axes._axes.Axes

# %%
ax=df.plot(kind="bar")
ax.set(title="random bar graph",
       xlabel="row no",
       ylabel="random no")
ax.legend().set_visible(True)

# %%
plt.style.use('seaborn-v0_8-whitegrid')

#subpllot of chol,age, thalach
fig, (ax0,ax1) = plt.subplots(nrows=2,
                              ncols=1,
                              figsize=(10,10),
                             sharex=True)
scatter= ax0.scatter(x=over_50["age"],
                     y=over_50["chol"],
                     c=over_50["target"],
                    cmap="winter")

#customize ax0
ax0.set(title="heart disease and chol levels",
        ylabel="chol")
ax0.legend(*scatter.legend_elements(),title="target")
ax0.axhline(y=over_50["chol"].mean(),
            linestyle="--")
ax0.set_xlim([50,80])

scatter= ax1.scatter(x=over_50["age"],
                     y=over_50["thalach"],
                     c=over_50["target"],
                    cmap="winter")

#customize ax1
ax1.set(title="heart disease and chol levels",
        xlabel="age",
        ylabel="thalach")
ax1.legend(*scatter.legend_elements(),title="target")
ax1.axhline(y=over_50["thalach"].mean(),
            linestyle="--")
ax1.set_ylim([60,200])

#add title to fig
fig.suptitle("heart disease analysis",fontsize=16,fontweight="bold");

# %%
fig

# %%
fig.savefig("heat-disease-analysis-plot.png")
